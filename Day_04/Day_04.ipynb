# %%
import pandas as pd

# %%
# Population data from GapMinder
population = pd.read_csv("/content/pop.csv")
population
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1          Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2         Albania   400k   402k   404k   405k   407k   409k   411k   413k
# 3         Andorra   2650   2650   2650   2650   2650   2650   2650   2650
# 4             UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192         Samoa  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.2k
# 193         Yemen  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M
# 194  South Africa  1.45M  1.45M  1.46M  1.46M  1.47M  1.47M  1.48M  1.49M
# 195        Zambia   747k   758k   770k   782k   794k   806k   818k   831k
# 196      Zimbabwe  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M
#
#       1808  ...   2091   2092   2093   2094   2095   2096   2097   2098  \
# 0    3.28M  ...   108M   108M   109M   109M   109M   110M   110M   110M
# 1    1.57M  ...   125M   126M   127M   128M   129M   130M   131M   131M
# 2     414k  ...  1.35M  1.32M  1.29M  1.26M  1.23M  1.21M  1.18M  1.15M
# 3     2650  ...  62.5k  62.2k  61.9k  61.7k  61.4k  61.2k  60.9k  60.7k
# 4    40.2k  ...  13.5M  13.5M  13.6M  13.7M  13.8M  13.8M  13.9M    14M
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192  47.2k  ...   432k   434k   435k   436k   437k   438k   439k   440k
# 193  2.59M  ...  73.2M  73.3M  73.5M  73.6M  73.7M  73.8M  73.9M    74M
# 194  1.49M  ...  75.6M  75.5M  75.4M  75.3M  75.2M  75.1M    75M  74.8M
# 195   843k  ...  60.3M  60.7M  61.1M  61.5M  61.9M  62.2M  62.6M  62.9M
# 196  1.09M  ...  35.1M  35.2M  35.3M  35.4M  35.4M  35.5M  35.5M  35.6M
#
#       2099   2100
# 0     111M   111M
# 1     132M   133M
# 2    1.12M   1.1M
# 3    60.5k  60.2k
# 4      14M  14.1M
# ..     ...    ...
# 192   441k   441k
# 193  74.1M  74.2M
# 194  74.7M  74.6M
# 195  63.3M  63.6M
# 196  35.6M  35.6M
#
# [197 rows x 302 columns]

# %%
#In order to convert our dataset from wide to long format we will use
long_population = population.melt(id_vars=["country"], var_name="year", value_name="population")
long_population
# Out:
#             country  year population
# 0       Afghanistan  1800      3.28M
# 1            Angola  1800      1.57M
# 2           Albania  1800       400k
# 3           Andorra  1800       2650
# 4               UAE  1800      40.2k
# ...             ...   ...        ...
# 59292         Samoa  2100       441k
# 59293         Yemen  2100      74.2M
# 59294  South Africa  2100      74.6M
# 59295        Zambia  2100      63.6M
# 59296      Zimbabwe  2100      35.6M
#
# [59297 rows x 3 columns]

# %%
wide_population = long_population.pivot(index = "country", columns = "year", values = "population")
wide_population = wide_population.reset_index()
wide_population
# Out:
# year      country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1         Albania   400k   402k   404k   405k   407k   409k   411k   413k
# 2         Algeria   2.5M  2.51M  2.52M  2.53M  2.54M  2.55M  2.56M  2.56M
# 3         Andorra   2650   2650   2650   2650   2650   2650   2650   2650
# 4          Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192     Venezuela     1M   978k   957k   936k   916k   896k   876k   857k
# 193       Vietnam     4M   4.1M   4.2M  4.31M  4.41M  4.53M  4.64M  4.75M
# 194         Yemen  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M
# 195        Zambia   747k   758k   770k   782k   794k   806k   818k   831k
# 196      Zimbabwe  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M
#
# year   1808  ...   2091   2092   2093   2094   2095   2096   2097   2098  \
# 0     3.28M  ...   108M   108M   109M   109M   109M   110M   110M   110M
# 1      414k  ...  1.35M  1.32M  1.29M  1.26M  1.23M  1.21M  1.18M  1.15M
# 2     2.57M  ...  67.8M  67.9M  67.9M  67.9M  67.9M  67.9M  67.9M  67.9M
# 3      2650  ...  62.5k  62.2k  61.9k  61.7k  61.4k  61.2k  60.9k  60.7k
# 4     1.57M  ...   125M   126M   127M   128M   129M   130M   131M   131M
# ..      ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192    838k  ...  36.5M  36.4M  36.3M  36.2M    36M  35.9M  35.8M  35.6M
# 193   4.87M  ...  94.9M  94.5M    94M  93.6M  93.2M  92.8M  92.3M  91.9M
# 194   2.59M  ...  73.2M  73.3M  73.5M  73.6M  73.7M  73.8M  73.9M    74M
# 195    843k  ...  60.3M  60.7M  61.1M  61.5M  61.9M  62.2M  62.6M  62.9M
# 196   1.09M  ...  35.1M  35.2M  35.3M  35.4M  35.4M  35.5M  35.5M  35.6M
#
# year   2099   2100
# 0      111M   111M
# 1     1.12M   1.1M
# 2     67.8M  67.8M
# 3     60.5k  60.2k
# 4      132M   133M
# ..      ...    ...
# 192   35.5M  35.4M
# 193   91.5M    91M
# 194   74.1M  74.2M
# 195   63.3M  63.6M
# 196   35.6M  35.6M
#
# [197 rows x 302 columns]

# %% [markdown]
# Joining Datasets in Python
#
# The information you need is often spread across multiple data sets, so you will need to combine multiple data sets into one. In this chapter, we discuss strategies for combining information from multiple (tabular) data sets.

# %%
#Babies name for 1995

data_dir = "http://dlsun.github.io/pods/data/names/"
names1995 = pd.read_csv(data_dir + "yob1995.txt",
                        header=None,
                        names=["Name", "Sex", "Count"])
names1995
# Out:
#            Name Sex  Count
# 0       Jessica   F  27935
# 1        Ashley   F  26603
# 2         Emily   F  24378
# 3      Samantha   F  21646
# 4         Sarah   F  21369
# ...         ...  ..    ...
# 26075     Zerek   M      5
# 26076      Zhen   M      5
# 26077     Ziggy   M      5
# 26078    Zuberi   M      5
# 26079      Zyon   M      5
#
# [26080 rows x 3 columns]

# %%
# Babies name for 2015
names2015 = pd.read_csv(data_dir + "yob2015.txt",
                        header=None,# you caa remove this and it will show empty
                        names=["Name", "Sex", "Count"])# and if you remove this then the names of colums are empty
names2015
# Out:
#            Name Sex  Count
# 0          Emma   F  20455
# 1        Olivia   F  19691
# 2        Sophia   F  17417
# 3           Ava   F  16378
# 4      Isabella   F  15617
# ...         ...  ..    ...
# 33116    Zykell   M      5
# 33117    Zyking   M      5
# 33118     Zykir   M      5
# 33119     Zyrus   M      5
# 33120      Zyus   M      5
#
# [33121 rows x 3 columns]

# %%
#  we can add a Year column to each DataFrame before we concatenate.
names1995["Year"] = 1995
names2015["Year"] = 2015
names = pd.concat([names1995, names2015], ignore_index=True)
names
# Out:
#            Name Sex  Count  Year
# 0       Jessica   F  27935  1995
# 1        Ashley   F  26603  1995
# 2         Emily   F  24378  1995
# 3      Samantha   F  21646  1995
# 4         Sarah   F  21369  1995
# ...         ...  ..    ...   ...
# 59196    Zykell   M      5  2015
# 59197    Zyking   M      5  2015
# 59198     Zykir   M      5  2015
# 59199     Zyrus   M      5  2015
# 59200      Zyus   M      5  2015
#
# [59201 rows x 4 columns]

# %%
# Mix both the datasets which will hekp you to analyze easily
pd.concat([names1995, names2015])
# Out:
#            Name Sex  Count  Year
# 0       Jessica   F  27935  1995
# 1        Ashley   F  26603  1995
# 2         Emily   F  24378  1995
# 3      Samantha   F  21646  1995
# 4         Sarah   F  21369  1995
# ...         ...  ..    ...   ...
# 33116    Zykell   M      5  2015
# 33117    Zyking   M      5  2015
# 33118     Zykir   M      5  2015
# 33119     Zyrus   M      5  2015
# 33120      Zyus   M      5  2015
#
# [59201 rows x 4 columns]

# %% [markdown]
# Mergining:
#
# The process of combining columns or variables from different data sets is known as merging or joining.
#
# This naming convention is reflected in the syntax of the .merge() function in pandas. In the code below, the “left” DataFrame, names1995, is quite literally on the left in the code, while the “right” DataFrame, names2015, is to the right. We also specify the variables to match across the two DataFrames.

# %%
# combined name and sex in both the year and give the count
names1995.merge(names2015, on=["Name", "Sex"])
# Out:
#            Name Sex  Count_x  Year_x  Count_y  Year_y
# 0       Jessica   F    27935    1995     1587    2015
# 1        Ashley   F    26603    1995     3424    2015
# 2         Emily   F    24378    1995    11786    2015
# 3      Samantha   F    21646    1995     5340    2015
# 4         Sarah   F    21369    1995     4521    2015
# ...         ...  ..      ...     ...      ...     ...
# 15675    Zephan   M        5    1995       23    2015
# 15676  Zeppelin   M        5    1995       70    2015
# 15677     Zerek   M        5    1995        5    2015
# 15678     Ziggy   M        5    1995       44    2015
# 15679      Zyon   M        5    1995      148    2015
#
# [15680 rows x 6 columns]

# %%
# suffixes = the paramter names in this it what the both years
names1995.merge(names2015, on=["Name", "Sex"], suffixes=("1995", "2015"))
# Out:
#            Name Sex  Count1995  Year1995  Count2015  Year2015
# 0       Jessica   F      27935      1995       1587      2015
# 1        Ashley   F      26603      1995       3424      2015
# 2         Emily   F      24378      1995      11786      2015
# 3      Samantha   F      21646      1995       5340      2015
# 4         Sarah   F      21369      1995       4521      2015
# ...         ...  ..        ...       ...        ...       ...
# 15675    Zephan   M          5      1995         23      2015
# 15676  Zeppelin   M          5      1995         70      2015
# 15677     Zerek   M          5      1995          5      2015
# 15678     Ziggy   M          5      1995         44      2015
# 15679      Zyon   M          5      1995        148      2015
#
# [15680 rows x 6 columns]

# %%
# Create new DataFrames where the column names are different
names2015_ = names2015.rename({"Sex": "Gender"}, axis=1)

# This is how you merge them.
names1995.merge(
    names2015_,
    left_on=("Name", "Sex"),
    right_on=("Name", "Gender")
)
# Out:
#            Name Sex  Count_x  Year_x Gender  Count_y  Year_y
# 0       Jessica   F    27935    1995      F     1587    2015
# 1        Ashley   F    26603    1995      F     3424    2015
# 2         Emily   F    24378    1995      F    11786    2015
# 3      Samantha   F    21646    1995      F     5340    2015
# 4         Sarah   F    21369    1995      F     4521    2015
# ...         ...  ..      ...     ...    ...      ...     ...
# 15675    Zephan   M        5    1995      M       23    2015
# 15676  Zeppelin   M        5    1995      M       70    2015
# 15677     Zerek   M        5    1995      M        5    2015
# 15678     Ziggy   M        5    1995      M       44    2015
# 15679      Zyon   M        5    1995      M      148    2015
#
# [15680 rows x 7 columns]

# %% [markdown]
# Types of Joins
#
# inner join (default): only values that are present in both DataFrames are included in the result
#
# outer join: any value that appears in either DataFrame is included in the result
#
# left join: any value that appears in the left DataFrame is included in the result, whether or not it appears in the right DataFrame
#
# right join: any value that appears in the right DataFrame is included in the result, whether or not it appears in the left DataFrame.

# %%
names1995 = pd.read_csv(data_dir + "yob1995.txt",
                        header=None, names=["Name", "Sex", "Count"])
names2005 = pd.read_csv(data_dir + "yob2005.txt",
                        header=None, names=["Name", "Sex", "Count"])

# %%
# inner join
names_inner = names1995.merge(names2005, on=["Name", "Sex"], how="inner")
names_inner
# Out:
#            Name Sex  Count_x  Count_y
# 0       Jessica   F    27935     8108
# 1        Ashley   F    26603    13270
# 2         Emily   F    24378    23930
# 3      Samantha   F    21646    13633
# 4         Sarah   F    21369    11527
# ...         ...  ..      ...      ...
# 19119  Zeppelin   M        5        7
# 19120     Zerek   M        5        8
# 19121      Zhen   M        5        7
# 19122     Ziggy   M        5        6
# 19123      Zyon   M        5      102
#
# [19124 rows x 4 columns]

# %%
# outer join
names_outer = names1995.merge(names2005, on=["Name", "Sex"], how="outer")
names_outer
# Out:
#             Name Sex  Count_x  Count_y
# 0        Jessica   F  27935.0   8108.0
# 1         Ashley   F  26603.0  13270.0
# 2          Emily   F  24378.0  23930.0
# 3       Samantha   F  21646.0  13633.0
# 4          Sarah   F  21369.0  11527.0
# ...          ...  ..      ...      ...
# 39490    Zymiere   M      NaN      5.0
# 39491     Zyrell   M      NaN      5.0
# 39492     Zyrian   M      NaN      5.0
# 39493     Zyshon   M      NaN      5.0
# 39494  Zytavious   M      NaN      5.0
#
# [39495 rows x 4 columns]

# %%
# left join
names_left = names1995.merge(names2005, on=["Name", "Sex"], how="left")
names_left
# Out:
#            Name Sex  Count_x  Count_y
# 0       Jessica   F    27935   8108.0
# 1        Ashley   F    26603  13270.0
# 2         Emily   F    24378  23930.0
# 3      Samantha   F    21646  13633.0
# 4         Sarah   F    21369  11527.0
# ...         ...  ..      ...      ...
# 26075     Zerek   M        5      8.0
# 26076      Zhen   M        5      7.0
# 26077     Ziggy   M        5      6.0
# 26078    Zuberi   M        5      NaN
# 26079      Zyon   M        5    102.0
#
# [26080 rows x 4 columns]

# %%
# right join
names_right = names1995.merge(names2005, on=["Name", "Sex"], how="right")
names_right
# Out:
#             Name Sex  Count_x  Count_y
# 0          Emily   F  24378.0    23930
# 1           Emma   F   5041.0    20335
# 2        Madison   F   9775.0    19562
# 3        Abigail   F   7821.0    15747
# 4         Olivia   F   7624.0    15691
# ...          ...  ..      ...      ...
# 32534    Zymiere   M      NaN        5
# 32535     Zyrell   M      NaN        5
# 32536     Zyrian   M      NaN        5
# 32537     Zyshon   M      NaN        5
# 32538  Zytavious   M      NaN        5
#
# [32539 rows x 4 columns]
